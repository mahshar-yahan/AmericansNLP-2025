# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/shipibo-konibo-spanish/train.es
# /kaggle/input/shipibo-konibo-spanish/dev.shp
# /kaggle/input/shipibo-konibo-spanish/train.shp
# /kaggle/input/shipibo-konibo-spanish/dev.es
# /kaggle/input/shipibo-konibo-spanish/test.shp-es.src
# /kaggle/input/shipibo-konibo-spanish/test.es-shp.src

# %%
# %%capture
# %pip install sentencepiece transformers==4.33 datasets sacremoses sacrebleu -q

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, NllbTokenizer
from transformers.optimization import Adafactor
from transformers import get_constant_schedule_with_warmup
from sklearn.model_selection import train_test_split
import re
import random
from tqdm.auto import tqdm
import os

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
HUGGINGFACE_TOKEN = user_secrets.get_secret("HUGGINGFACE_TOKEN")

# !huggingface-cli login --token $HUGGINGFACE_TOKEN
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `basic task` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `basic task`

# %% [markdown]
# ## Dataset

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []
spanish_lines = []
source = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/shipibo-konibo-spanish/train.shp', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# # Read train.cni (Ashaninka) file
# with open('/kaggle/input/awajun-spanish/dev.source', 'r', encoding='utf-8') as file:
#     source = [line.strip() for line in file]

# Read train.es (Spanish) file
with open('/kaggle/input/shipibo-konibo-spanish/train.es', 'r', encoding='utf-8') as file:
    spanish_lines = [line.strip() for line in file]

# Create a DataFrame
train_df  = pd.DataFrame({
    # 'Source': source,
    'Shipibo': ashaninka_lines,
    'Spanish': spanish_lines
})

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []
spanish_lines = []
source = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/shipibo-konibo-spanish/dev.shp', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# # Read train.cni (Ashaninka) file
# with open('/kaggle/input/awajun-spanish/dev.source', 'r', encoding='utf-8') as file:
#     source = [line.strip() for line in file]

# Read train.es (Spanish) file
with open('/kaggle/input/shipibo-konibo-spanish/dev.es', 'r', encoding='utf-8') as file:
    spanish_lines = [line.strip() for line in file]

# Create a DataFrame
dev_df  = pd.DataFrame({
    # 'Source': source,
    'Shipibo': ashaninka_lines,
    'Spanish': spanish_lines
})

# %%
# Create a test set from the dev data
dev_df, test_df = train_test_split(dev_df, test_size=0.5, random_state=42)

# %%
print(f"Training samples: {len(train_df)}")
print(f"Development samples: {len(dev_df)}")
print(f"Test samples: {len(test_df)}")
# Out:
# Training samples: 14592
# Development samples: 498
# Test samples: 498

# %%
# Step 4: Initialize the NLLB tokenizer and model
model_name = "facebook/nllb-200-distilled-600M"
tokenizer = NllbTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:488: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %% [markdown]
# ## Examine tokenization

# %%
def word_tokenize(text):
    return re.findall('(\w+|[^\w\s])', text)

# %%
# Sample from the training data
sample = train_df.sample(min(10000, len(train_df)), random_state=1)

# %%
# Apply tokenization
sample['shp_toks'] = sample.Shipibo.apply(tokenizer.tokenize)
sample['spa_toks'] = sample.Spanish.apply(tokenizer.tokenize)
sample['shp_words'] = sample.Shipibo.apply(word_tokenize)
sample['spa_words'] = sample.Spanish.apply(word_tokenize)

# %%
# Compute statistics
stats = sample[['shp_toks', 'spa_toks', 'shp_words', 'spa_words']].applymap(len).describe()
# Out:
# <ipython-input-13-e94ff85eaed3>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   stats = sample[['shp_toks', 'spa_toks', 'shp_words', 'spa_words']].applymap(len).describe()

# %%
print("Average tokens per word for Shipibo:", stats.shp_toks['mean'] / stats.shp_words['mean'])
print("Average tokens per word for Spanish:", stats.spa_toks['mean'] / stats.spa_words['mean'])
# Out:
# Average tokens per word for Shipibo: 2.048196010252182
# Average tokens per word for Spanish: 1.3095675924173178

# %%
# Check for unknown tokens
texts_with_unk_shp = [
    text for text in tqdm(train_df.Shipibo)
    if tokenizer.unk_token_id in tokenizer(text).input_ids
]

texts_with_unk_spa = [
    text for text in tqdm(train_df.Spanish)
    if tokenizer.unk_token_id in tokenizer(text).input_ids
]
# Out:
#   0%|          | 0/14592 [00:00<?, ?it/s]
#   0%|          | 0/14592 [00:00<?, ?it/s]

# %%
print(f"Number of Awajun texts with unknown tokens: {len(texts_with_unk_shp)}")
print(f"Number of Spanish texts with unknown tokens: {len(texts_with_unk_spa)}")
# Out:
# Number of Awajun texts with unknown tokens: 1
# Number of Spanish texts with unknown tokens: 0

# %% [markdown]
# ## Add Language Token if needed

# %%
def fix_tokenizer(tokenizer, new_lang='shp_Latn'):
    old_len = len(tokenizer) - int(new_lang in tokenizer.added_tokens_encoder)
    tokenizer.lang_code_to_id[new_lang] = old_len-1
    tokenizer.id_to_lang_code[old_len-1] = new_lang
    tokenizer.fairseq_tokens_to_ids["<mask>"] = len(tokenizer.sp_model) + len(tokenizer.lang_code_to_id) + tokenizer.fairseq_offset
    tokenizer.fairseq_tokens_to_ids.update(tokenizer.lang_code_to_id)
    tokenizer.fairseq_ids_to_tokens = {v: k for k, v in tokenizer.fairseq_tokens_to_ids.items()}
    if new_lang not in tokenizer._additional_special_tokens:
        tokenizer._additional_special_tokens.append(new_lang)
    tokenizer.added_tokens_encoder = {}
    tokenizer.added_tokens_decoder = {}

# %%
if 'agr_Latn' not in tokenizer.lang_code_to_id:
    fix_tokenizer(tokenizer, 'shp_Latn')
    model.resize_token_embeddings(len(tokenizer))
    
    # Initialize the embedding for the new token with a similar language
    added_token_id = tokenizer.convert_tokens_to_ids('shp_Latn')
    similar_lang_id = tokenizer.convert_tokens_to_ids('quy_Latn')  # Quechua is similar to Aymara
    embeds = model.model.shared.weight.data
    embeds[added_token_id] = embeds[similar_lang_id]
# Out:
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 256205. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc

# %% [markdown]
# ## Preprocess function for text

# %%
def preproc(text):
    from sacremoses import MosesPunctNormalizer
    mpn = MosesPunctNormalizer(lang="es")
    clean = mpn.normalize(text)
    return clean

# %% [markdown]
# ## Training function

# %%
def get_batch_pairs(batch_size, data=train_df):
    LANGS = [('Shipibo', 'shp_Latn'), ('Spanish', 'spa_Latn')]
    (l1, long1), (l2, long2) = random.sample(LANGS, 2)
    xx, yy = [], []
    for _ in range(batch_size):
        item = data.iloc[random.randint(0, len(data)-1)]
        xx.append(preproc(item[l1]))
        yy.append(preproc(item[l2]))
    return xx, yy, long1, long2

# %%
def train_model(model, tokenizer, training_steps=20000, batch_size=16, max_length=128, lr=1e-4):
    # Move model to GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    # Define optimizer and scheduler
    optimizer = Adafactor(
        [p for p in model.parameters() if p.requires_grad],
        scale_parameter=False,
        relative_step=False,
        lr=lr,
        clip_threshold=1.0,
        weight_decay=1e-3,
    )
    scheduler = get_constant_schedule_with_warmup(optimizer, num_warmup_steps=1000)
    
    # Training loop
    losses = []
    MODEL_SAVE_PATH = 'nllb-shp-spa-v1'
    os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
    
    model.train()
    x, y, loss = None, None, None
    
    def cleanup():
        import gc
        gc.collect()
        torch.cuda.empty_cache()
    
    for i in tqdm(range(training_steps)):
        xx, yy, lang1, lang2 = get_batch_pairs(batch_size)
        
        try:
            tokenizer.src_lang = lang1
            x = tokenizer(xx, return_tensors='pt', padding=True, truncation=True, max_length=max_length).to(device)
            tokenizer.src_lang = lang2
            y = tokenizer(yy, return_tensors='pt', padding=True, truncation=True, max_length=max_length).to(device)
            y.input_ids[y.input_ids == tokenizer.pad_token_id] = -100
            
            loss = model(**x, labels=y.input_ids).loss
            loss.backward()
            losses.append(loss.item())
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            scheduler.step()
            
        except RuntimeError as e:
            optimizer.zero_grad(set_to_none=True)
            x, y, loss = None, None, None
            cleanup()
            print('error', max(len(s) for s in xx + yy), e)
            continue
        
        if i % 1000 == 0:
            avg_loss = torch.mean(torch.tensor(losses[-1000:] if len(losses) > 1000 else losses))
            print(f"Step {i}, Average Loss: {avg_loss}")
            if i % 5000 == 0 and i > 0:
                model.save_pretrained(f"{MODEL_SAVE_PATH}/checkpoint-{i}")
                tokenizer.save_pretrained(f"{MODEL_SAVE_PATH}/checkpoint-{i}")
    
    # Save the final model
    model.save_pretrained(MODEL_SAVE_PATH)
    tokenizer.save_pretrained(MODEL_SAVE_PATH)
    
    return model, tokenizer

# %% [markdown]
# ## Evaluation function

# %%
def evaluate_model(model, tokenizer, test_data):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    # Function to translate text
    def translate(text, src_lang, tgt_lang, num_beams=4):
        tokenizer.src_lang = src_lang
        inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=1024)
        with torch.no_grad():
            outputs = model.generate(
                **inputs.to(device), 
                forced_bos_token_id=tokenizer.convert_tokens_to_ids(tgt_lang), 
                num_beams=num_beams
            )
        return tokenizer.batch_decode(outputs, skip_special_tokens=True)
    
    # Translate Aymara to Spanish
    agr_to_spa = []
    for text in tqdm(test_data.Shipibo):
        agr_to_spa.append(translate(text, 'shp_Latn', 'spa_Latn')[0])
    
    # Translate Spanish to Aymara
    spa_to_agr = []
    for text in tqdm(test_data.Spanish):
        spa_to_agr.append(translate(text, 'spa_Latn', 'shp_Latn')[0])
    
    # Calculate BLEU scores
    import sacrebleu
    
    bleu_agr_spa = sacrebleu.corpus_bleu(agr_to_spa, [test_data.Spanish.tolist()])
    bleu_spa_agr = sacrebleu.corpus_bleu(spa_to_agr, [test_data.Shipibo.tolist()])
    
    chrf_agr_spa = sacrebleu.corpus_chrf(agr_to_spa, [test_data.Spanish.tolist()])
    chrf_spa_agr = sacrebleu.corpus_chrf(spa_to_agr, [test_data.Shipibo.tolist()])
    
    # Calculate exact match accuracy
    agr_spa_exact_matches = sum(1 for pred, ref in zip(agr_to_spa, test_data.Spanish) if pred.strip() == ref.strip())
    spa_agr_exact_matches = sum(1 for pred, ref in zip(spa_to_agr, test_data.Shipibo) if pred.strip() == ref.strip())
    
    agr_spa_accuracy = (agr_spa_exact_matches / len(test_data)) * 100
    spa_agr_accuracy = (spa_agr_exact_matches / len(test_data)) * 100
    
    # Calculate word-level accuracy (percentage of words that match)
    def calculate_word_accuracy(predictions, references):
        total_words = 0
        correct_words = 0
        
        for pred, ref in zip(predictions, references):
            pred_words = pred.strip().split()
            ref_words = ref.strip().split()
            
            # Count words in reference
            total_words += len(ref_words)
            
            # Count matching words (position-sensitive)
            for i, ref_word in enumerate(ref_words):
                if i < len(pred_words) and pred_words[i] == ref_word:
                    correct_words += 1
        
        return (correct_words / total_words) * 100 if total_words > 0 else 0
    
    agr_spa_word_accuracy = calculate_word_accuracy(agr_to_spa, test_data.Spanish)
    spa_agr_word_accuracy = calculate_word_accuracy(spa_to_agr, test_data.Shipibo)
    
    print(f"BLEU Awajun → Spanish: {bleu_agr_spa.score:.2f}")
    print(f"BLEU Spanish → Awajun: {bleu_spa_agr.score:.2f}")
    print(f"chrF++ Awajun → Spanish: {chrf_agr_spa.score:.2f}")
    print(f"chrF++ Spanish → Awajun: {chrf_spa_agr.score:.2f}")
    print(f"Exact Match Accuracy Awajun → Spanish: {agr_spa_accuracy:.2f}%")
    print(f"Exact Match Accuracy Spanish → Awajun: {spa_agr_accuracy:.2f}%")
    print(f"Word-level Accuracy Awajun → Spanish: {agr_spa_word_accuracy:.2f}%")
    print(f"Word-level Accuracy Spanish → Awajun: {spa_agr_word_accuracy:.2f}%")
    
    return {
        'bleu_agr_spa': bleu_agr_spa.score,
        'bleu_spa_agr': bleu_spa_agr.score,
        'chrf_agr_spa': chrf_agr_spa.score,
        'chrf_spa_agr': chrf_spa_agr.score,
        'agr_spa_accuracy': agr_spa_accuracy,
        'spa_agr_accuracy': spa_agr_accuracy,
        'agr_spa_word_accuracy': agr_spa_word_accuracy,
        'spa_agr_word_accuracy': spa_agr_word_accuracy,
        'agr_to_spa_samples': list(zip(test_data.Shipibo.head(5), agr_to_spa[:5])),
        'spa_to_agr_samples': list(zip(test_data.Spanish.head(5), spa_to_agr[:5]))
    }

# %% [markdown]
# ## Main Execution

# %%
# Train the model
print("Starting model training...")
model, tokenizer = train_model(model, tokenizer, training_steps=20000) #Min 10000 steps need to be a good translator
# Out:
# Starting model training...
#   0%|          | 0/20000 [00:00<?, ?it/s]
# Step 0, Average Loss: 4.108303070068359
# Step 1000, Average Loss: 3.7379183769226074
# Step 2000, Average Loss: 2.399975061416626
# Step 3000, Average Loss: 1.9004802703857422
# Step 4000, Average Loss: 1.5846502780914307
# Step 5000, Average Loss: 1.3639267683029175
# Step 6000, Average Loss: 1.1964153051376343
# Step 7000, Average Loss: 1.0527374744415283
# Step 8000, Average Loss: 0.9114532470703125
# Step 9000, Average Loss: 0.8127791285514832
# Step 10000, Average Loss: 0.7035567760467529
# Step 11000, Average Loss: 0.6270449161529541
# Step 12000, Average Loss: 0.5593052506446838
# Step 13000, Average Loss: 0.48539987206459045
# Step 14000, Average Loss: 0.4236831068992615
# Step 15000, Average Loss: 0.37148332595825195
# Step 16000, Average Loss: 0.32922446727752686
# Step 17000, Average Loss: 0.29752472043037415
# Step 18000, Average Loss: 0.26406463980674744
# Step 19000, Average Loss: 0.23805639147758484

# %% [markdown]
# ## Hugging Face Model Push

# %%
model_name = "mahsharyahan/nllb-600B-shp-spa-v1"
tokenizer.push_to_hub(model_name)
model.push_to_hub(model_name)
# Out:
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/mahsharyahan/nllb-600B-shp-spa-v1/commit/ad4a885adf47ea77e434fe013cc569b4d7021354', commit_message='Upload M2M100ForConditionalGeneration', commit_description='', oid='ad4a885adf47ea77e434fe013cc569b4d7021354', pr_url=None, repo_url=RepoUrl('https://huggingface.co/mahsharyahan/nllb-600B-shp-spa-v1', endpoint='https://huggingface.co', repo_type='model', repo_id='mahsharyahan/nllb-600B-shp-spa-v1'), pr_revision=None, pr_num=None)

# %%
# Evaluate the model
print("Evaluating the model...")
eval_results = evaluate_model(model, tokenizer, test_df)
# Out:
# Evaluating the model...
#   0%|          | 0/498 [00:00<?, ?it/s]
#   0%|          | 0/498 [00:00<?, ?it/s]
# BLEU Awajun → Spanish: 5.22
# BLEU Spanish → Awajun: 1.30
# chrF++ Awajun → Spanish: 27.33
# chrF++ Spanish → Awajun: 21.65
# Exact Match Accuracy Awajun → Spanish: 1.00%
# Exact Match Accuracy Spanish → Awajun: 0.20%
# Word-level Accuracy Awajun → Spanish: 6.80%
# Word-level Accuracy Spanish → Awajun: 3.02%

# %% [markdown]
# ## Sample Testing

# %%
# Print some translation examples
print("\Shipibo to Spanish translation examples:")
for src, tgt in eval_results['agr_to_spa_samples']:
    print(f"Source: {src}")
    print(f"Translation: {tgt}")
    print()

print("\nSpanish to Awajun translation examples:")
for src, tgt in eval_results['spa_to_agr_samples']:
    print(f"Source: {src}")
    print(f"Translation: {tgt}")
    print()
# Out:
# \Shipibo to Spanish translation examples:
# Source: jaskara riki, itan ea kikini rabikainke jawerato compañía betan ikai akin yoiya kamanres
# Translation: así es, y tengo mucha vergüenza de ir a buscar compañías de aseo.
#
# Source: Jatian en ninkake moa kaires, jakopira en ati iwana jawekibo ramapari keyoi itai.
# Translation: Entonces escuche que ya iba, y por eso las cosas que debería hacer ahora van a terminar.
#
# Source: Consejo de Fideicomisarios ronki presidenteoma iki.
# Translation: El consejo de los fideicomisiarios no tiene presidente.
#
# Source: Jaskaribira min atipanke non oferta menbresia 2 baritia senen ikai kaman 30 $ kopi ati, 60 % kaman min ahorranai 2 baritiakaman.
# Translation: Podrías hacer tu propina de 2 años hasta llegar a los 30 dólares, y hasta el 60 por ciento te pagarás hasta los 2 años.
#
# Source: Yapa pené, rono riki jatibi ja alfonbra senenain ika.
# Translation: El pescado, la serpiente y todas las plantas pertenecen al reino vegetal.
#
#
# Spanish to Awajun translation examples:
# Source: exacto, y me sentí muy halagado hasta que me dijo que la compañía con la que estaba
# Translation: enra rotóque, jatíbi nocon báqueranon ea yóiaquin.
#
# Source: Y entonces le escuché irse, por lo que aún  estoy acabando lo que tenía que hacer.
# Translation: Játianra en nincáque moa cáa; jácopira en senénquiai jahuéquiati.
#
# Source: El Consejo de Fideicomisarios no tiene presidente.
# Translation: Jóniconia córi rimántanra ápooma iqui.
#
# Source: También puedes aprovechar nuestra oferta de membresía especial de 2 años por 30 $, un ahorro de casi el 60 % en el precio habitual de 2 años.
# Translation: Non rabé báritianoxonbi min átipanon jahuen nóshi copira min átipanque, non rabé báritianoxonbi min ácai senénhaquin.
#
# Source: Pez dorado, serpientes son todo lo que está en el borde de la alfombra.
# Translation: Koshín, róno riqui jatíbi jahuéqui tapón quexa.

# %% [markdown]
# ## Submit Function

# %%
def test_translation_without_targets(model, tokenizer, test_data, src_lang, tgt_lang, num_samples=5):
    import torch
    from tqdm.auto import tqdm
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    # Determine column name based on language direction
    if src_lang == 'shp_Latn':
        src_col = 'Shipibo'
    else:
        src_col = 'Spanish'
    
    # Function to translate text
    def translate(text, num_beams=4, max_length=128):
        tokenizer.src_lang = src_lang
        inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
        with torch.no_grad():
            outputs = model.generate(
                **inputs.to(device), 
                forced_bos_token_id=tokenizer.convert_tokens_to_ids(tgt_lang), 
                num_beams=num_beams,
                max_length=max_length
            )
        return tokenizer.batch_decode(outputs, skip_special_tokens=True)
    
    # Translate test samples
    translations = []
    
    # Select random samples for detailed review
    test_samples = test_data.sample(min(num_samples, len(test_data)))
    
    # Process all test data
    print(f"\n===== Translation Results: {src_lang} to {tgt_lang} =====")
    print("Sample Translations:")
    
    for i, (_, row) in enumerate(tqdm(test_data.iterrows(), total=len(test_data), desc=f"Translating {src_lang} to {tgt_lang}")):
        source_text = row[src_col]
        translated_text = translate(source_text)[0]
        translations.append(translated_text)
        
        # Display detailed examples for the selected samples
        if _ in test_samples.index:
            print(f"\nExample {i+1}:")
            print(f"Source ({src_col}): {source_text}")
            print(f"Translation: {translated_text}")
    
    return translations

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/shipibo-konibo-spanish/test.shp-es.src', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# Create a DataFrame
df_test_agr_es = pd.DataFrame({
    # 'Source': source,
    'Shipibo': ashaninka_lines,
})

# %%
agr_to_es_results = test_translation_without_targets(model, tokenizer, df_test_agr_es, 'shp_Latn', 'spa_Latn')
# Out:
# ===== Translation Results: shp_Latn to spa_Latn =====
# Sample Translations:
# Translating shp_Latn to spa_Latn:   0%|          | 0/1003 [00:00<?, ?it/s]
# Example 59:
# Source (Shipibo): Locust Hillra ja mejor iki.
# Translation: La cabecera de la cueva es la mejor.
#
# Example 315:
# Source (Shipibo): Noara trasladametaa iki bena residenciain.
# Translation: Deberíamos quedarnos trasladados.
#
# Example 486:
# Source (Shipibo): Ja sayara kikin chixkoshoko iki itan jakopira shokores noyai.
# Translation: Aquel vuelo es muy pequeño y vuela mucho rápido.
#
# Example 594:
# Source (Shipibo): Nato Señora Faulkora en onanshamayamake, jara 80 baritia keska ikatiai, itan kikin jakon ainbora ikatiai, jawetiakinra en oinke, ikaxbi jakopira ea kikin nerviosares ike.
# Translation: No sé a esta señorita, ella casi cumple los ochenta años, y ella siempre me parece una buena mujer, muchos vi, pero por el contrario estoy muy nerviosa.
#
# Example 770:
# Source (Shipibo): Enra yoike rama bewakan versiónra nokon ken akin.
# Translation: He dicho que ahora me gusta la canción.

# %%
# Create a DataFrame
df_test_result_agr_to_es = pd.DataFrame({
    # 'Source': source,
    'Spanish': agr_to_es_results,
})

# %%
df_test_result_agr_to_es.to_csv('test_result_shp_to_es.tsv', sep='\t', index=False, header=False)

# %%
from IPython.display import FileLink

FileLink("test_result_shp_to_es.tsv")
# Out:
# /kaggle/working/test_result_shp_to_es.tsv

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/shipibo-konibo-spanish/test.shp-es.src', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# Create a DataFrame
df_test_es_arg = pd.DataFrame({
    # 'Source': source,
    'Spanish': ashaninka_lines,
})

# %%
es_to_agr_results = test_translation_without_targets(model, tokenizer, df_test_es_arg, 'spa_Latn','shp_Latn')
# Out:
# ===== Translation Results: spa_Latn to shp_Latn =====
# Sample Translations:
# Translating spa_Latn to shp_Latn:   0%|          | 0/1003 [00:00<?, ?it/s]
# Example 109:
# Source (Spanish): Ramabira ea westiora bake ainbo maxkoya iki itan jain botikoma riki itan ja, ikaxbira en, eh...
# Translation: Ramabira ea westiora bake ainbo maxkoya iki jain botioma riki itan ja, ixonbi ea, eh...
#
# Example 164:
# Source (Spanish): Jara yoyo ikai kimisha submarinobo keskaki.
# Translation: Jara yoyo ikai kimisha ninkatai.
#
# Example 224:
# Source (Spanish): Rabe mekenbe utilizanwe nato control de armabo practicankasai ixon.
# Translation: Rabe mekenbaon nato bewa ninkati iki mia axekasai ixon.
#
# Example 714:
# Source (Spanish): Ja jain ikatiai westiora, jara ika iki westiora ministronin bake, jaskara iakax ja jaya ika iki, jatora propiedadesboya ika iki, itan wetsa jawekibo riki, itan kikini jakoni conectameta ika iki jemanko itan ikatiai kikin akin, kikin akin estimankana.
# Translation: Jain ika westiora, jara ika westiora ministon bake, jaskara ika ja jaya ika, jawen jawekibo ika ikain iki, itan wetsa jawekibo riki, itan kikini jakoni yoyo ikinwe ika iki jemankoni itan ikatonin kikin akin, kikin akin jatibi.
#
# Example 775:
# Source (Spanish): Janra ea yoike jawen información financiera bexonti.
# Translation: Janra yoike jawen jawekibo oinxon.

# %%
# Create a DataFrame
df_test_result_es_to_agr = pd.DataFrame({
    # 'Source': source,
    'Shipibo': es_to_agr_results,
})

# %%
df_test_result_es_to_agr.to_csv('test_result_es_to_shp.tsv', sep='\t', index=False, header=False)

# %%
from IPython.display import FileLink

FileLink("test_result_es_to_shp.tsv")
# Out:
# /kaggle/working/test_result_es_to_shp.tsv
