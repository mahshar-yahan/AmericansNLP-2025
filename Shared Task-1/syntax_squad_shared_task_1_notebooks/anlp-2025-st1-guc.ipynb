# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/wayuu-spanish/train.es
# /kaggle/input/wayuu-spanish/test.guc-es.src
# /kaggle/input/wayuu-spanish/train.guc
# /kaggle/input/wayuu-spanish/test.es-guc.src
# /kaggle/input/wayuu-spanish/dev.guc
# /kaggle/input/wayuu-spanish/dev.es

# %%
# %%capture
# %pip install sentencepiece transformers==4.33 datasets sacremoses sacrebleu -q

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, NllbTokenizer
from transformers.optimization import Adafactor
from transformers import get_constant_schedule_with_warmup
from sklearn.model_selection import train_test_split
import re
import random
from tqdm.auto import tqdm
import os

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
HUGGINGFACE_TOKEN = user_secrets.get_secret("HUGGINGFACE_TOKEN")

# !huggingface-cli login --token $HUGGINGFACE_TOKEN
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `basic task` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `basic task`

# %% [markdown]
# ## Dataset

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []
spanish_lines = []
source = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/wayuu-spanish/train.guc', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# # Read train.cni (Ashaninka) file
# with open('/kaggle/input/awajun-spanish/dev.source', 'r', encoding='utf-8') as file:
#     source = [line.strip() for line in file]

# Read train.es (Spanish) file
with open('/kaggle/input/wayuu-spanish/train.es', 'r', encoding='utf-8') as file:
    spanish_lines = [line.strip() for line in file]

# Create a DataFrame
train_df  = pd.DataFrame({
    # 'Source': source,
    'Wayuu': ashaninka_lines,
    'Spanish': spanish_lines
})

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []
spanish_lines = []
source = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/wayuu-spanish/dev.es', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# # Read train.cni (Ashaninka) file
# with open('/kaggle/input/awajun-spanish/dev.source', 'r', encoding='utf-8') as file:
#     source = [line.strip() for line in file]

# Read train.es (Spanish) file
with open('/kaggle/input/wayuu-spanish/dev.es', 'r', encoding='utf-8') as file:
    spanish_lines = [line.strip() for line in file]

# Create a DataFrame
dev_df  = pd.DataFrame({
    # 'Source': source,
    'Wayuu': ashaninka_lines,
    'Spanish': spanish_lines
})

# %%
# Create a test set from the dev data
dev_df, test_df = train_test_split(dev_df, test_size=0.5, random_state=42)

# %%
print(f"Training samples: {len(train_df)}")
print(f"Development samples: {len(dev_df)}")
print(f"Test samples: {len(test_df)}")
# Out:
# Training samples: 59715
# Development samples: 3317
# Test samples: 3318

# %%
# Step 4: Initialize the NLLB tokenizer and model
model_name = "facebook/nllb-200-distilled-600M"
tokenizer = NllbTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:488: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location=map_location)
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %% [markdown]
# ## Examine tokenization

# %%
def word_tokenize(text):
    return re.findall('(\w+|[^\w\s])', text)

# %%
# Sample from the training data
sample = train_df.sample(min(10000, len(train_df)), random_state=1)

# %%
# Apply tokenization
sample['guc_toks'] = sample.Wayuu.apply(tokenizer.tokenize)
sample['spa_toks'] = sample.Spanish.apply(tokenizer.tokenize)
sample['guc_words'] = sample.Wayuu.apply(word_tokenize)
sample['spa_words'] = sample.Spanish.apply(word_tokenize)

# %%
# Compute statistics
stats = sample[['guc_toks', 'spa_toks', 'guc_words', 'spa_words']].applymap(len).describe()
# Out:
# <ipython-input-13-b21bfddba190>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   stats = sample[['guc_toks', 'spa_toks', 'guc_words', 'spa_words']].applymap(len).describe()

# %%
print("Average tokens per word for Wayuu:", stats.guc_toks['mean'] / stats.guc_words['mean'])
print("Average tokens per word for Spanish:", stats.spa_toks['mean'] / stats.spa_words['mean'])
# Out:
# Average tokens per word for Wayuu: 1.9980192040582159
# Average tokens per word for Spanish: 1.2648018648018646

# %%
# Check for unknown tokens
texts_with_unk_guc = [
    text for text in tqdm(train_df.Wayuu)
    if tokenizer.unk_token_id in tokenizer(text).input_ids
]

texts_with_unk_spa = [
    text for text in tqdm(train_df.Spanish)
    if tokenizer.unk_token_id in tokenizer(text).input_ids
]
# Out:
#   0%|          | 0/59715 [00:00<?, ?it/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1150 > 1024). Running this sequence through the model will result in indexing errors
#   0%|          | 0/59715 [00:00<?, ?it/s]

# %%
print(f"Number of Wayuu texts with unknown tokens: {len(texts_with_unk_guc)}")
print(f"Number of Spanish texts with unknown tokens: {len(texts_with_unk_spa)}")
# Out:
# Number of Wayuu texts with unknown tokens: 2336
# Number of Spanish texts with unknown tokens: 1392

# %% [markdown]
# ## Add Language Token if needed

# %%
def fix_tokenizer(tokenizer, new_lang='guc_Latn'):
    old_len = len(tokenizer) - int(new_lang in tokenizer.added_tokens_encoder)
    tokenizer.lang_code_to_id[new_lang] = old_len-1
    tokenizer.id_to_lang_code[old_len-1] = new_lang
    tokenizer.fairseq_tokens_to_ids["<mask>"] = len(tokenizer.sp_model) + len(tokenizer.lang_code_to_id) + tokenizer.fairseq_offset
    tokenizer.fairseq_tokens_to_ids.update(tokenizer.lang_code_to_id)
    tokenizer.fairseq_ids_to_tokens = {v: k for k, v in tokenizer.fairseq_tokens_to_ids.items()}
    if new_lang not in tokenizer._additional_special_tokens:
        tokenizer._additional_special_tokens.append(new_lang)
    tokenizer.added_tokens_encoder = {}
    tokenizer.added_tokens_decoder = {}

# %%
if 'guc_Latn' not in tokenizer.lang_code_to_id:
    fix_tokenizer(tokenizer, 'guc_Latn')
    model.resize_token_embeddings(len(tokenizer))
    
    # Initialize the embedding for the new token with a similar language
    added_token_id = tokenizer.convert_tokens_to_ids('guc_Latn')
    similar_lang_id = tokenizer.convert_tokens_to_ids('quy_Latn')  # Quechua is similar to Aymara
    embeds = model.model.shared.weight.data
    embeds[added_token_id] = embeds[similar_lang_id]
# Out:
# You are resizing the embedding layer without providing a `pad_to_multiple_of` parameter. This means that the new embedding dimension will be 256205. This might induce some performance reduction as *Tensor Cores* will not be available. For more details about this, or help on choosing the correct value for resizing, refer to this guide: https://docs.nvidia.com/deeplearning/performance/dl-performance-matrix-multiplication/index.html#requirements-tc

# %% [markdown]
# ## Preprocess function for text(Normalizer)

# %%
def preproc(text):
    from sacremoses import MosesPunctNormalizer
    mpn = MosesPunctNormalizer(lang="en")
    clean = mpn.normalize(text)
    return clean

# %% [markdown]
# ## Training function

# %%
def get_batch_pairs(batch_size, data=train_df):
    LANGS = [('Wayuu', 'guc_Latn'), ('Spanish', 'spa_Latn')]
    (l1, long1), (l2, long2) = random.sample(LANGS, 2)
    xx, yy = [], []
    for _ in range(batch_size):
        item = data.iloc[random.randint(0, len(data)-1)]
        xx.append(preproc(item[l1]))
        yy.append(preproc(item[l2]))
    return xx, yy, long1, long2

# %%
def train_model(model, tokenizer, training_steps=20000, batch_size=16, max_length=128, lr=1e-4):
    # Move model to GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    # Define optimizer and scheduler
    optimizer = Adafactor(
        [p for p in model.parameters() if p.requires_grad],
        scale_parameter=False,
        relative_step=False,
        lr=lr,
        clip_threshold=1.0,
        weight_decay=1e-3,
    )
    scheduler = get_constant_schedule_with_warmup(optimizer, num_warmup_steps=1000)
    
    # Training loop
    losses = []
    MODEL_SAVE_PATH = 'nllb-guc-spa-v1'
    os.makedirs(MODEL_SAVE_PATH, exist_ok=True)
    
    model.train()
    x, y, loss = None, None, None
    
    def cleanup():
        import gc
        gc.collect()
        torch.cuda.empty_cache()
    
    for i in tqdm(range(training_steps)):
        xx, yy, lang1, lang2 = get_batch_pairs(batch_size)
        
        try:
            tokenizer.src_lang = lang1
            x = tokenizer(xx, return_tensors='pt', padding=True, truncation=True, max_length=max_length).to(device)
            tokenizer.src_lang = lang2
            y = tokenizer(yy, return_tensors='pt', padding=True, truncation=True, max_length=max_length).to(device)
            y.input_ids[y.input_ids == tokenizer.pad_token_id] = -100
            
            loss = model(**x, labels=y.input_ids).loss
            loss.backward()
            losses.append(loss.item())
            optimizer.step()
            optimizer.zero_grad(set_to_none=True)
            scheduler.step()
            
        except RuntimeError as e:
            optimizer.zero_grad(set_to_none=True)
            x, y, loss = None, None, None
            cleanup()
            print('error', max(len(s) for s in xx + yy), e)
            continue
        
        if i % 1000 == 0:
            avg_loss = torch.mean(torch.tensor(losses[-1000:] if len(losses) > 1000 else losses))
            print(f"Step {i}, Average Loss: {avg_loss}")
            if i % 5000 == 0 and i > 0:
                model.save_pretrained(f"{MODEL_SAVE_PATH}/checkpoint-{i}")
                tokenizer.save_pretrained(f"{MODEL_SAVE_PATH}/checkpoint-{i}")
    
    # Save the final model
    model.save_pretrained(MODEL_SAVE_PATH)
    tokenizer.save_pretrained(MODEL_SAVE_PATH)
    
    return model, tokenizer

# %% [markdown]
# ## Evaluation function

# %%
def evaluate_model(model, tokenizer, test_data):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    # Function to translate text
    def translate(text, src_lang, tgt_lang, num_beams=4):
        tokenizer.src_lang = src_lang
        inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=1024)
        with torch.no_grad():
            outputs = model.generate(
                **inputs.to(device), 
                forced_bos_token_id=tokenizer.convert_tokens_to_ids(tgt_lang), 
                num_beams=num_beams
            )
        return tokenizer.batch_decode(outputs, skip_special_tokens=True)
    
    # Translate Aymara to Spanish
    guc_to_spa = []
    for text in tqdm(test_data.Wayuu):
        guc_to_spa.append(translate(text, 'guc_Latn', 'spa_Latn')[0])
    
    # Translate Spanish to Aymara
    spa_to_guc = []
    for text in tqdm(test_data.Spanish):
        spa_to_guc.append(translate(text, 'spa_Latn', 'guc_Latn')[0])
    
    # Calculate BLEU scores
    import sacrebleu
    
    bleu_guc_spa = sacrebleu.corpus_bleu(guc_to_spa, [test_data.Spanish.tolist()])
    bleu_spa_guc = sacrebleu.corpus_bleu(spa_to_guc, [test_data.Wayuu.tolist()])
    
    chrf_guc_spa = sacrebleu.corpus_chrf(guc_to_spa, [test_data.Spanish.tolist()])
    chrf_spa_guc = sacrebleu.corpus_chrf(spa_to_guc, [test_data.Wayuu.tolist()])
    
    # Calculate exact match accuracy
    guc_spa_exact_matches = sum(1 for pred, ref in zip(guc_to_spa, test_data.Spanish) if pred.strip() == ref.strip())
    spa_guc_exact_matches = sum(1 for pred, ref in zip(spa_to_guc, test_data.Wayuu) if pred.strip() == ref.strip())
    
    guc_spa_accuracy = (guc_spa_exact_matches / len(test_data)) * 100
    spa_guc_accuracy = (spa_guc_exact_matches / len(test_data)) * 100
    
    # Calculate word-level accuracy (percentage of words that match)
    def calculate_word_accuracy(predictions, references):
        total_words = 0
        correct_words = 0
        
        for pred, ref in zip(predictions, references):
            pred_words = pred.strip().split()
            ref_words = ref.strip().split()
            
            # Count words in reference
            total_words += len(ref_words)
            
            # Count matching words (position-sensitive)
            for i, ref_word in enumerate(ref_words):
                if i < len(pred_words) and pred_words[i] == ref_word:
                    correct_words += 1
        
        return (correct_words / total_words) * 100 if total_words > 0 else 0
    
    guc_spa_word_accuracy = calculate_word_accuracy(guc_to_spa, test_data.Spanish)
    spa_guc_word_accuracy = calculate_word_accuracy(spa_to_guc, test_data.Wayuu)
    
    print(f"BLEU Wayuu → Spanish: {bleu_guc_spa.score:.2f}")
    print(f"BLEU Spanish → Wayuu: {bleu_spa_guc.score:.2f}")
    print(f"chrF++ Wayuu → Spanish: {chrf_guc_spa.score:.2f}")
    print(f"chrF++ Spanish → Wayuu: {chrf_spa_guc.score:.2f}")
    print(f"Exact Match Accuracy Wayuu → Spanish: {guc_spa_accuracy:.2f}%")
    print(f"Exact Match Accuracy Spanish → Wayuu: {spa_guc_accuracy:.2f}%")
    print(f"Word-level Accuracy Wayuu → Spanish: {guc_spa_word_accuracy:.2f}%")
    print(f"Word-level Accuracy Spanish → Wayuu: {spa_guc_word_accuracy:.2f}%")
    
    return {
        'bleu_guc_spa': bleu_guc_spa.score,
        'bleu_spa_guc': bleu_spa_guc.score,
        'chrf_guc_spa': chrf_guc_spa.score,
        'chrf_spa_guc': chrf_spa_guc.score,
        'guc_spa_accuracy': guc_spa_accuracy,
        'spa_guc_accuracy': spa_guc_accuracy,
        'guc_spa_word_accuracy': guc_spa_word_accuracy,
        'spa_guc_word_accuracy': spa_guc_word_accuracy,
        'guc_to_spa_samples': list(zip(test_data.Wayuu.head(5), guc_to_spa[:5])),
        'spa_to_guc_samples': list(zip(test_data.Spanish.head(5), spa_to_guc[:5]))
    }

# %% [markdown]
# ## Main Execution

# %%
# Train the model
print("Starting model training...")
model, tokenizer = train_model(model, tokenizer, training_steps=30000) #Min 10000 steps need to be a good translator
# Out:
# Starting model training...
#   0%|          | 0/30000 [00:00<?, ?it/s]
# Step 0, Average Loss: 8.068519592285156
# Step 1000, Average Loss: 4.0200886726379395
# Step 2000, Average Loss: 2.873680591583252
# Step 3000, Average Loss: 2.560354232788086
# Step 4000, Average Loss: 2.3949105739593506
# Step 5000, Average Loss: 2.2344279289245605
# Step 6000, Average Loss: 2.129990577697754
# Step 7000, Average Loss: 2.0629987716674805
# Step 8000, Average Loss: 1.9943071603775024
# Step 9000, Average Loss: 1.9007478952407837
# Step 10000, Average Loss: 1.8760383129119873
# Step 11000, Average Loss: 1.8030478954315186
# Step 12000, Average Loss: 1.7698124647140503
# Step 13000, Average Loss: 1.7153089046478271
# Step 14000, Average Loss: 1.6915867328643799
# Step 15000, Average Loss: 1.6456799507141113
# Step 16000, Average Loss: 1.6126573085784912
# Step 17000, Average Loss: 1.5929758548736572
# Step 18000, Average Loss: 1.5453180074691772
# Step 19000, Average Loss: 1.5077329874038696
# Step 20000, Average Loss: 1.4985040426254272
# Step 21000, Average Loss: 1.4562981128692627
# Step 22000, Average Loss: 1.405856728553772
# Step 23000, Average Loss: 1.4135078191757202
# Step 24000, Average Loss: 1.3754138946533203
# Step 25000, Average Loss: 1.3435508012771606
# Step 26000, Average Loss: 1.3381611108779907
# Step 27000, Average Loss: 1.3166009187698364
# Step 28000, Average Loss: 1.2792537212371826
# Step 29000, Average Loss: 1.2597031593322754

# %% [markdown]
# ## Hugging Face Model Push

# %%
model_name = "mahsharyahan/nllb-600B-guc-spa-v1"
tokenizer.push_to_hub(model_name)
model.push_to_hub(model_name)
# Out:
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/mahsharyahan/nllb-600B-guc-spa-v1/commit/db3b65c0bf98f3abf5231f1a71c6a5f4c8831977', commit_message='Upload M2M100ForConditionalGeneration', commit_description='', oid='db3b65c0bf98f3abf5231f1a71c6a5f4c8831977', pr_url=None, repo_url=RepoUrl('https://huggingface.co/mahsharyahan/nllb-600B-guc-spa-v1', endpoint='https://huggingface.co', repo_type='model', repo_id='mahsharyahan/nllb-600B-guc-spa-v1'), pr_revision=None, pr_num=None)

# %%
# Evaluate the model
print("Evaluating the model...")
eval_results = evaluate_model(model, tokenizer, test_df)
# Out:
# Evaluating the model...
#   0%|          | 0/3318 [00:00<?, ?it/s]
#   0%|          | 0/3318 [00:00<?, ?it/s]
# BLEU Wayuu → Spanish: 72.53
# BLEU Spanish → Wayuu: 0.36
# chrF++ Wayuu → Spanish: 84.49
# chrF++ Spanish → Wayuu: 12.58
# Exact Match Accuracy Wayuu → Spanish: 46.68%
# Exact Match Accuracy Spanish → Wayuu: 0.33%
# Word-level Accuracy Wayuu → Spanish: 62.18%
# Word-level Accuracy Spanish → Wayuu: 0.40%

# %% [markdown]
# ## Sample Testing

# %%
# Print some translation examples
print("\Awajun to Spanish translation examples:")
for src, tgt in eval_results['guc_to_spa_samples']:
    print(f"Source: {src}")
    print(f"Translation: {tgt}")
    print()

print("\nSpanish to Awajun translation examples:")
for src, tgt in eval_results['spa_to_guc_samples']:
    print(f"Source: {src}")
    print(f"Translation: {tgt}")
    print()
# Out:
# \Awajun to Spanish translation examples:
# Source: lo enterraron vivo
# Translation: el enterraron vivo
#
# Source: que es la modestia y que no es
# Translation: que es la modestia y que no
#
# Source: si es posible criar buenos hijos en un mundo malo
# Translation: si es posible criar buenos hijos en un mundo malo
#
# Source: por a os estas explicaciones fortalecieron la fe de muchos hermanos
# Translation: por muchos a os estas explicaciones han fortalecido la fe de muchos
#
# Source: las profecias de la biblia se cumplieron
# Translation: las profecias de la biblia se cumplieron
#
#
# Spanish to Awajun translation examples:
# Source: lo enterraron vivo
# Translation: ojoitünüshi kataa o'u
#
# Source: que es la modestia y que no es
# Translation: nnojotsü yaletüin waa'in
#
# Source: si es posible criar buenos hijos en un mundo malo
# Translation: jamüsü süpüla anainjatüin nakuwa'ipa na tepichikana süpüla ne'ikajaain naya sulu'u tü mma mojulaasükalüirua
#
# Source: por a os estas explicaciones fortalecieron la fe de muchos hermanos
# Translation: sutuma tia atütülaasü nanoula na wawalayuukana
#
# Source: las profecias de la biblia se cumplieron
# Translation: ekeraajüsü tü sümakat tü wiwüliakat

# %% [markdown]
# ## Submit Function

# %%
def test_translation_without_targets(model, tokenizer, test_data, src_lang, tgt_lang, num_samples=5):
    import torch
    from tqdm.auto import tqdm
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    
    # Determine column name based on language direction
    if src_lang == 'guc_Latn':
        src_col = 'Wayuu'
    else:
        src_col = 'Spanish'
    
    # Function to translate text
    def translate(text, num_beams=4, max_length=128):
        tokenizer.src_lang = src_lang
        inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=max_length)
        with torch.no_grad():
            outputs = model.generate(
                **inputs.to(device), 
                forced_bos_token_id=tokenizer.convert_tokens_to_ids(tgt_lang), 
                num_beams=num_beams,
                max_length=max_length
            )
        return tokenizer.batch_decode(outputs, skip_special_tokens=True)
    
    # Translate test samples
    translations = []
    
    # Select random samples for detailed review
    test_samples = test_data.sample(min(num_samples, len(test_data)))
    
    # Process all test data
    print(f"\n===== Translation Results: {src_lang} to {tgt_lang} =====")
    print("Sample Translations:")
    
    for i, (_, row) in enumerate(tqdm(test_data.iterrows(), total=len(test_data), desc=f"Translating {src_lang} to {tgt_lang}")):
        source_text = row[src_col]
        translated_text = translate(source_text)[0]
        translations.append(translated_text)
        
        # Display detailed examples for the selected samples
        if _ in test_samples.index:
            print(f"\nExample {i+1}:")
            print(f"Source ({src_col}): {source_text}")
            print(f"Translation: {translated_text}")
    
    return translations

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/wayuu-spanish/test.es-guc.src', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# Create a DataFrame
df_test_guc_es = pd.DataFrame({
    # 'Source': source,
    'Wayuu': ashaninka_lines,
})

# %%
guc_to_es_results = test_translation_without_targets(model, tokenizer, df_test_guc_es, 'guc_Latn', 'spa_Latn')
# Out:
# ===== Translation Results: guc_Latn to spa_Latn =====
# Sample Translations:
# Translating guc_Latn to spa_Latn:   0%|          | 0/498 [00:00<?, ?it/s]
# Example 53:
# Source (Wayuu): —Menos mal —pensé yo—, que he comido ración doble.
# Translation: Menos  mal
#
# Example 105:
# Source (Wayuu): Se alejaron tomados de la mano y llegaron a la parte superior plana de la pared al pie del bosque.
# Translation: Se alejaron tomados de la mano y llegaron a la parte superior plana de la pared al pie del bosque.
#
# Example 116:
# Source (Wayuu): porque, en este caso, el peso de nuestro planeta sería dos veces menor.
# Translation: porque en este caso el peso de nuestro planeta seria dos veces menor.
#
# Example 218:
# Source (Wayuu): Aquí había llegado en mis sueños, cuando mi tío, descargando sobre la mesa un terrible puñetazo, me volvió a la realidad de una manera violenta.
# Translation: Aquí había llegado en mis sueños, cuando mi tío, descargando sobre la mesa un terriblemente bonito, me volvía a la realidad de una manera violenta.
#
# Example 276:
# Source (Wayuu): —¿Y su cena?
# Translation: ¿Y su cena?

# %%
# Create a DataFrame
df_test_result_guc_to_es = pd.DataFrame({
    # 'Source': source,
    'Spanish': guc_to_es_results,
})

# %%
df_test_result_guc_to_es.to_csv('test_result_guc_to_es.tsv', sep='\t', index=False, header=False)

# %%
from IPython.display import FileLink

FileLink("test_result_guc_to_es.tsv")
# Out:
# /kaggle/working/test_result_guc_to_es.tsv

# %%
# Initialize lists to store the lines from each file
ashaninka_lines = []

# Read train.cni (Ashaninka) file
with open('/kaggle/input/wayuu-spanish/test.guc-es.src', 'r', encoding='utf-8') as file:
    ashaninka_lines = [line.strip() for line in file]

# Create a DataFrame
df_test_es_guc = pd.DataFrame({
    # 'Source': source,
    'Spanish': ashaninka_lines,
})

# %%
es_to_guc_results = test_translation_without_targets(model, tokenizer, df_test_es_guc, 'spa_Latn','guc_Latn')
# Out:
# ===== Translation Results: spa_Latn to guc_Latn =====
# Sample Translations:
# Translating spa_Latn to guc_Latn:   0%|          | 0/498 [00:00<?, ?it/s]
# Example 114:
# Source (Spanish): shouu abril,wana'suma apünajünaa sünain tü pote loza sulujatukalüü tü supulakalü ekirajaapülee Shiasa'a sha'watüin sünain ourajaa chii jokomakai, o'unawaishi wanepiaa wattamalüü supúla nujutünüin tü supanaka mojuui supúla muloumatutchin'nia
# Translation: so'u juyaka aa'uriiro'u, wanaa sümaa sü'yonoojünüin sünain tü pootshisükat sulu'u tü süpüleekat ekirajiapüleerua Shiasa'a süchikijee sha'watüin sünain o'uraajaa jokomakai chii, ojutuushi wanee pueulo watta ma'in süpüla ojutuunuin tü sapanakalü mojuui supula mulo'u ma'in
#
# Example 259:
# Source (Spanish): —Shia'jo tia shiolojo wüinkalu akuwaipa antunerrü anain onoipain sain suküwaipa, maka sain palairruku, tu paalaka counanainsü shia'jo sütüma tu kashikat chuwatapa shia, shia'sa muin, piama süülia sulerrüje süpüla kaikat anü'jo, ayalerrüin suküwaipa tü maapakalü, katumakalü jaichirrüin'jo sukutkajawalinn tu maapakalü wanepia
# Translation: Shiasa'a süpülapünaa sülatüin tü juyakat antüshi süpüla eeinjatüin wayuu eekai anain süpülapünaa sülatüin, makalaka anain palairruku, tü pükatalakalüirua süpüla shi'yataainjatüin sütüma tü kashikalüirua süpüla shi'yotüinjatüin shia, tü piamasükat süpüla sülatüinjatüin ka'i, süpüla sülatüin
#
# Example 342:
# Source (Spanish): Tu kulut nüshempalakat sü jemiyaii süma tü nusapatsekat Pedro etasü'jo jayashin palastüin nao chi wayunkerra aataajiakai wuchi, ainjúshi sükaa laula tam-o'-shanter numüin McGregor.
# Translation: Tü süpüshikalüirua nüma'ana sümaa nüsapaatse Pedro, ja'yasü süpa'apünaa tü mmakat chi waüchi o'unajaakai, o'unüshi süka laula tam-oꞌu-'shanter nünainmüin mcgregor.
#
# Example 343:
# Source (Spanish): —Shiasa'jo kapülein shia —tamaka, süma muin tejepulain ain sulü nojolüin tanoujuin sain suküwaipa sulü nojolüin wanawain tain suma'jo tü akuwaipakalü.
# Translation: Nnojolüitpa kasain saamüin sümüin, süka nnojolüin tachecherüin taa'in sünain anoujaa süka nnojolüin wanaawain sümaa tü takuaippakat.
#
# Example 463:
# Source (Spanish): ¿nojotsu pi'rüin? numaka tamüin -,¿nojotsu pi'rüin? Shia wane kasaa kojutasantasu süma nojolut kalin shia kasa sumaiwajatüka tatta'anain waptapa sulu' nupia chi judío Hevelius.
# Translation: Nümakalaka tamüin: - ¿Nnojotsü pi'rüin? Nnojotsü pi'rüin. Shia tü kasa kojutükat ma'i sümaa nnojolüin kojutüin shia. Shia tü kasa e'itaanakat wapüleerua nüpüshi chi wayuu judío kanüliashi Hevelio.

# %%
# Create a DataFrame
df_test_result_es_to_guc = pd.DataFrame({
    # 'Source': source,
    'Wayuu': es_to_guc_results,
})

# %%
df_test_result_es_to_guc.to_csv('test_result_es_to_guc.tsv', sep='\t', index=False, header=False)

# %%
from IPython.display import FileLink

FileLink("test_result_es_to_guc.tsv")
# Out:
# /kaggle/working/test_result_es_to_guc.tsv
